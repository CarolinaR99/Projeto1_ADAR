# %% [markdown]
# # Load CSV

# %%
import pandas as pd
df = pd.read_csv("../n1_data_and_annotations.csv")
df.head(4)
# Out:
#         ROC-LOC       LOC-ROC         F2-F4         F4-C4         C4-P4  \
# 0 -2.625284e-06  2.625284e-06 -7.173382e-07  2.213065e-06  2.335165e-06
# 1 -4.578984e-07  4.578984e-07 -1.297314e-06  1.633089e-06  2.594628e-07
# 2 -4.884249e-07  4.884249e-07 -1.678877e-07 -4.578755e-08 -2.274115e-06
# 3 -3.846346e-06  3.846346e-06  1.205739e-06 -1.144689e-06 -2.762515e-06
#
#           P4-O2     F1-F3         F3-C3         C3-P3         P3-O1  ...  \
# 0  3.510379e-07 -0.000005  6.517094e-06  7.463370e-06  1.358364e-06  ...
# 1 -1.068376e-07 -0.000007  3.952991e-06  6.364469e-06  1.785714e-06  ...
# 2 -1.297314e-06 -0.000005  4.731380e-07  2.090965e-06  3.815629e-07  ...
# 3 -1.572039e-06 -0.000003 -6.257631e-07  6.257631e-07 -4.731380e-07  ...
#
#    TERMISTORE    TORACE    ADDOME       Dx1-DX2       SX1-SX2  Posizione  \
# 0   -0.000059  0.000111 -0.000360  2.899347e-07 -7.172069e-07        3.0
# 1   -0.000052  0.000094 -0.000317  2.899347e-07  2.288958e-07        3.0
# 2   -0.000061  0.000118 -0.000378 -1.525972e-08 -4.730513e-07        3.0
# 3   -0.000066  0.000132 -0.000415 -1.373375e-07 -4.577916e-08        3.0
#
#           HR       SpO2       times  sleepstage
# 0  75.083543  95.017929  210.000000           W
# 1  75.083543  95.017929  210.007812           W
# 2  75.083543  95.017929  210.015625           W
# 3  75.083543  95.017929  210.023438           W
#
# [4 rows x 23 columns]

# %% [markdown]
# # MIN-MAX SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
new_df = df.iloc[:,:-2]

new_df.head(4)
print(scaler.fit(new_df))

print(scaler.data_max_)
df_norm = scaler.transform(new_df)
df_norm = pd.DataFrame(df_norm)
df_norm['times'] = df['times']
df_norm['sleepstage'] = df['sleepstage']
df_norm.columns = df.columns
df_norm.head(4)
# Out:
# MinMaxScaler()
# [4.11223246e-04 4.07590586e-04 5.60332723e-04 3.62652625e-04
#  3.93177656e-04 1.00022894e-03 5.52335165e-04 3.11034799e-04
#  6.67170330e-04 5.70985958e-04 3.89819902e-04 1.72758489e-04
#  5.75215162e-04 2.59030316e-04 6.35172827e-03 6.36161123e-03
#  8.26878472e-04 8.34691448e-04 3.00000000e+00 9.00679026e+01
#  9.90218967e+01]
#     ROC-LOC   LOC-ROC     F2-F4     F4-C4     C4-P4     P4-O2     F1-F3  \
# 0  0.494576  0.505424  0.342891  0.501856  0.598709  0.381495  0.569009
# 1  0.497223  0.502777  0.342212  0.501055  0.596578  0.381212  0.568089
# 2  0.497185  0.502815  0.343534  0.498734  0.593976  0.380476  0.569552
# 3  0.493084  0.506916  0.345143  0.497216  0.593475  0.380306  0.570943
#
#       F3-C3     C3-P3     P3-O1  ...  TERMISTORE    TORACE    ADDOME  \
# 0  0.641009  0.540942  0.497184  ...    0.384376  0.509000  0.471837
# 1  0.637986  0.540177  0.497562  ...    0.397430  0.507660  0.475217
# 2  0.633884  0.537203  0.496322  ...    0.380598  0.509504  0.470422
# 3  0.632588  0.536184  0.495568  ...    0.370515  0.510627  0.467503
# 4400636  ...    0.000014 -0.000354  0.000172  4.855185e-04 -1.050327e-04
# 4400637  ...    0.000010 -0.000438  0.000456  1.116554e-04  1.076573e-04
# 4400638  ...    0.000014 -0.000361  0.000264 -2.507630e-04 -9.242813e-05
# 4400639  ...    0.000029 -0.000069 -0.000566 -4.318959e-04  9.990539e-05
#
#          Posizione         HR       SpO2         times  sleepstage
# 0              3.0  75.083543  95.017929    210.000000           W
# 1              3.0  75.083543  95.017929    210.007812           W
# 2              3.0  75.083543  95.017929    210.015625           W
# 3              3.0  75.083543  95.017929    210.023438           W
# 4              3.0  75.083543  95.017929    210.031250           W
# ...            ...        ...        ...           ...         ...
# 4400635        3.0  72.080568  97.019913  34589.960938           W
# 4400636        3.0  72.080568  97.019913  34589.968750           W
# 4400637        3.0  72.080568  97.019913  34589.976562           W
# 4400638        3.0  72.080568  97.019913  34589.984375           W
# 4400639        3.0  72.080568  97.019913  34589.992188           W
#
# [4400640 rows x 23 columns]>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,5))
#plt.plot(norm["times"],norm["ROC-LOC"]*2)
#plt.plot(norm["times"],norm["LOC-ROC"]*2)
#plt.plot(norm["times"],norm["F2-F4"]*2)
#plt.plot(norm["times"],norm["F4-C4"]*2)
#plt.plot(norm["times"],norm["C4-P4"]*2)
#plt.plot(norm["times"],norm["P4-O2"]*3)
#plt.plot(norm["times"],norm["F1-F3"]*3)
#plt.plot(norm["times"],norm["F3-C3"]*3)
#plt.plot(norm["times"],norm["C3-P3"]*3)
#plt.plot(norm["times"],norm["P3-O1"]*3)
#plt.plot(norm["times"],norm["C4-A1"])
#plt.plot(norm["times"],norm["EMG1-EMG2"]*3)
#plt.plot(norm["times"],norm["ECG1-ECG2"])
#plt.plot(norm["times"],norm["TERMISTORE"])
#plt.plot(norm["times"],norm["TORACE"])
#plt.plot(norm["times"],norm["ADDOME"])
#plt.plot(norm["times"],norm["Dx1-DX2"]*2)
#plt.plot(norm["times"],norm["SX1-SX2"])
#plt.plot(norm["times"],norm["Posizione"])
#plt.plot(norm["times"],norm["HR"]*2)
#plt.plot(norm["times"],norm["SpO2"]*3)
plt.plot(df_norm["times"],(df_norm["sleepstage"]))

# %%
selected_data=df_norm[["times","F2-F4","F4-C4","C4-P4","P4-O2","F1-F3","F3-C3","C3-P3","P3-O1"]]

# %% [markdown]
# # ICA

# %%
from sklearn.decomposition import FastICA

#X, A = w.result
ica_model = FastICA(n_components=9, random_state=0)
X_transformed = ica_model.fit_transform(selected_data)

# %%
f, ax = plt.subplots(9, 2, figsize=(25, 5))
_ = ax[0,0].plot(selected_data[["times"]], selected_data[["F2-F4"]], 'o')
_ = ax[0,1].plot(X_transformed[:, 0], X_transformed[:, 1], 'o')
_ = ax[0,0].set_title("Captured Distribution")
_ = ax[0,1].set_title("ICA components")

_ = ax[1,0].plot(selected_data[["times"]], selected_data[["F4-C4"]], 'o')
_ = ax[1,1].plot(X_transformed[:, 0], X_transformed[:, 2], 'o')
_ = ax[1,0].set_title("Captured Distribution")
_ = ax[1,1].set_title("ICA components")

_ = ax[2,0].plot(selected_data[["times"]], selected_data[["C4-P4"]], 'o')
_ = ax[2,1].plot(X_transformed[:, 0], X_transformed[:, 3], 'o')
_ = ax[2,0].set_title("Captured Distribution")
_ = ax[2,1].set_title("ICA components")
